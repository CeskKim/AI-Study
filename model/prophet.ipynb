# %% [markdown]
# <a href="https://colab.research.google.com/github/CeskKim/AI-Study/blob/main/model/prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prophet quick start
import pandas as pd
from prophet import Prophet

# source data
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()

# fit setting
m = Prophet()
m.fit(df)

future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaqlgr2hx/g25fkx5r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaqlgr2hx/jqkxgxem.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25112', 'data', 'file=/tmp/tmpaqlgr2hx/g25fkx5r.json', 'init=/tmp/tmpaqlgr2hx/jqkxgxem.json', 'output', 'file=/tmp/tmpaqlgr2hx/prophet_modelbj_khq10/prophet_model-20230218121851.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:18:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:18:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# stock python package
# !pip install finance-datareader
import FinanceDataReader as fdr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# btc stock
bitcoin_stock = fdr.DataReader('BTC/KRW', '2022-12-01', '2023-02-18')
bitcoin_stock.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-02-14  27760044.0  28240970.0  27563498.0  28278196.0  28278196.0
# 2023-02-15  28277916.0  31213578.0  28250184.0  31213578.0  31213578.0
# 2023-02-16         NaN         NaN         NaN         NaN         NaN
# 2023-02-17         NaN         NaN         NaN         NaN         NaN
# 2023-02-18  31818654.0  32043548.0  31712138.0  31856266.0  31856266.0
#
#                   Volume
# Date
# 2023-02-14  3.409626e+13
# 2023-02-15  4.171166e+13
# 2023-02-16           NaN
# 2023-02-17           NaN
# 2023-02-18  4.675171e+13

# %%
# prophet model
from prophet import Prophet
bitcoin_stock = fdr.DataReader('BTC/KRW', '2022-12-01', '2023-02-18')
bitcoin_stock.tail()
bitcoin_stock['y'] = bitcoin_stock['Close']
bitcoin_stock['ds'] = bitcoin_stock.index

pr = Prophet()
pr.fit(bitcoin_stock)

# prophet prediction period
future = pr.make_future_dataframe(periods=60)
forecast = pr.predict(future)
forecast.tail()
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].iloc[-40:-20]
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2bdaykko/lclvjj46.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2bdaykko/130qn_05.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62139', 'data', 'file=/tmp/tmp2bdaykko/lclvjj46.json', 'init=/tmp/tmp2bdaykko/130qn_05.json', 'output', 'file=/tmp/tmp2bdaykko/prophet_modelwvgcq432/prophet_model-20230218122001.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:20:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:20:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...

# %%
# btc 7주일 기준 측정
